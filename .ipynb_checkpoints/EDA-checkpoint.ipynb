# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# With reference to 'WB Data Cleanup.py'; this space will be used to highlight the reasons for the steps chosen to clean the World Bank extracted data. __Check how to hide input cells such that it remains hidden when uploading to github__

# %% [markdown]
# ### Libs

# %%
import pandas as pd
import numpy as np
from functools import reduce
from xgboost import XGBRegressor
from xgboost import plot_importance
import wbpy
import wbdata
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from plotnine import *
import warnings
import missingno as msno
warnings.filterwarnings('ignore')

# %%
Train.shape
# Out:
# (12744, 1650)

# %%
Train.head()
# Out:
#               Urban population (% of total)  Urban population  \
# country date
# Aruba   2018                            NaN               NaN
#         2017                         43.293           45572.0
#         2016                         43.192           45275.0
#         2015                         43.108           44979.0
#         2014                         43.041           44674.0
#
#               Urban population growth (annual %)  \
# country date
# Aruba   2018                                 NaN
#         2017                            0.653849
#         2016                            0.655929
#         2015                            0.680404
#         2014                            0.705351
#
#               Rural population (% of total population)  \
# country date
# Aruba   2018                                       NaN
#         2017                                    56.707
#         2016                                    56.808
#         2015                                    56.892
#         2014                                    56.959
#
#               Rural population growth (annual %)  Rural population  \
# country date
# Aruba   2018                                 NaN               NaN
#         2017                            0.243209           59692.0
#         2016                            0.311163           59547.0
#         2015                            0.406810           59362.0
#         2014                            0.498526           59121.0
#
#               Population, male (% of total)  Population, male  \
# country date
# Aruba   2018                            NaN               NaN
#         2017                      47.482329           49982.0
#         2016                      47.508515           49799.0
#         2015                      47.534479           49598.0
#         2014                      47.572208           49378.0
#
#               Population, female (% of total)  Population, female  ...  \
# country date                                                       ...
# Aruba   2018                              NaN                 NaN  ...
#         2017                        52.517671             55282.0  ...
#         2016                        52.491485             55023.0  ...
#         2015                        52.465521             54743.0  ...
#         2014                        52.427792             54417.0  ...
#
#               HOI: Mathematics Proficiency Level 2  \
# country date
# Aruba   2018                                   NaN
#         2017                                   NaN
#         2016                                   NaN
#         2015                                   NaN
#         2014                                   NaN
#
#               HOI: Mathematics Proficiency Level 2, Private schools  \
# country date
# Aruba   2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#         2014                                                NaN
#
#               HOI: Mathematics Proficiency Level 2, Public schools  \
# country date
# Aruba   2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#         2014                                                NaN
#
#               HOI: Mathematics Proficiency Level 3  \
# country date
# Aruba   2018                                   NaN
#         2017                                   NaN
#         2016                                   NaN
#         2015                                   NaN
#         2014                                   NaN
#
#               HOI: Mathematics Proficiency Level 3, Private schools  \
# country date
# Aruba   2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#         2014                                                NaN
#
#               HOI: Mathematics Proficiency Level 3, Public schools  \
# country date
# Aruba   2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#         2014                                                NaN
#
#               HOI: Reading Proficiency Level 2  \
# country date
# Aruba   2018                               NaN
#         2017                               NaN
#         2016                               NaN
#         2015                               NaN
#         2014                               NaN
#
#               HOI: Reading Proficiency Level 2, Private schools  \
# country date
# Aruba   2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#         2014                                                NaN
#
#               HOI: Reading Proficiency Level 2, Public schools  \
# country date
# Aruba   2018                                               NaN
#         2017                                               NaN
#         2016                                               NaN
#         2015                                               NaN
#         2014                                               NaN
#
#               HOI: Reading Proficiency Level 3
# country date
# Aruba   2018                               NaN
#         2017                               NaN
#         2016                               NaN
#         2015                               NaN
#         2014                               NaN
#
# [5 rows x 1650 columns]

# %%
Train.isnull().sum()
# Out:
# Urban population (% of total)                                                 398
# Urban population                                                              439
# Urban population growth (annual %)                                            443
# Rural population (% of total population)                                      398
# Rural population growth (annual %)                                            872
# Rural population                                                              439
# Population, male (% of total)                                                1616
# Population, male                                                             1619
# Population, female (% of total)                                              1616
# Population, female                                                           1619
# Population, total                                                             323
# Population growth (annual %)                                                  328
# Age dependency ratio, young (% of working-age population)                    1619
# Age dependency ratio, old (% of working-age population)                      1619
# Age dependency ratio (% of working-age population)                           1619
# Sex ratio at birth (male births per female births)                           8703
# Population density (people per sq. km of land area)                           791
# Agricultural machinery, tractors                                             6636
# Fertilizer consumption (% of fertilizer production)                         11588
# Fertilizer consumption (kilograms per hectare of arable land)               10361
# Agricultural land (sq. km)                                                   2144
# Agricultural land (% of land area)                                           2156
# Arable land (hectares)                                                       2287
# Arable land (hectares per person)                                            2330
# Arable land (% of land area)                                                 2293
# Land under cereal production (hectares)                                      3574
# Permanent cropland (% of land area)                                          2852
# Rural land area where elevation is below 5 meters (sq. km)                  12207
# Rural land area where elevation is below 5 meters (% of total land area)    12207
# Urban land area where elevation is below 5 meters (sq. km)                  12207
#                                                                             ...
# Coverage: Mathematics Proficiency Level 3, Private schools                  12724
# Coverage: Mathematics Proficiency Level 3, Public schools                   12724
# Coverage: Reading Proficiency Level 2                                       12724
# Coverage: Reading Proficiency Level 2, Private schools                      12724
# Coverage: Reading Proficiency Level 2, Public schools                       12724
# Coverage: Reading Proficiency Level 3                                       12724
# Coverage: Reading Proficiency Level 3, Private schools                      12724
# Coverage: Reading Proficiency Level 3, Public schools                       12724
# Coverage: Sanitation                                                        12697
# Coverage: School Enrollment                                                 12694
# Coverage: Science Proficiency Level 2                                       12724
# Coverage: Science Proficiency Level 2, Private schools                      12724
# Coverage: Science Proficiency Level 2, Public schools                       12724
# Coverage: Science Proficiency Level 3                                       12724
# Coverage: Science Proficiency Level 3, Private schools                      12724
# Coverage: Science Proficiency Level 3, Public schools                       12724
# Coverage: Water                                                             12697
# HOI: Mobile Phone                                                           12707
# HOI: Electricity                                                            12700
# HOI: Internet                                                               12712
# HOI: Mathematics Proficiency Level 2                                        12724
# HOI: Mathematics Proficiency Level 2, Private schools                       12724
# HOI: Mathematics Proficiency Level 2, Public schools                        12724
# HOI: Mathematics Proficiency Level 3                                        12724
# HOI: Mathematics Proficiency Level 3, Private schools                       12724
# HOI: Mathematics Proficiency Level 3, Public schools                        12724
# HOI: Reading Proficiency Level 2                                            12724
# HOI: Reading Proficiency Level 2, Private schools                           12724
# HOI: Reading Proficiency Level 2, Public schools                            12724
# HOI: Reading Proficiency Level 3                                            12724
# Length: 1650, dtype: int64

# %% [markdown]
# __Clearly, missing values are a major issue. Some columns are completely empty.__

# %%
print('Avg missing values per feature:',np.int(Train.isnull().sum().mean()))
print('Percentage:',np.int((Train.isnull().sum().mean()/len(Train)*100)))
# Out:
# Avg missing values per feature: 8565
# Percentage: 67

# %% [markdown]
# __Given the average missing values above, seems reasonable to remove features (columns) with 80% or more missing values__

# %%
MV=Train.isnull().sum()
droplist=[i for i,j in MV.items() if (j/len(Train))>=0.8]
Train.drop(labels=droplist,axis=1,inplace=True)
Train.shape
# Out:
# (12744, 1031)
